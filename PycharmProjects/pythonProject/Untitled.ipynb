# %%
import pandas as pd

# %%
df = pd.read_csv("D:/time_series_list__2023-02-25_12_46.csv",sep=";")

# %%
df.head()
# Out:
#   Компонент Модуль  Версія Сума  \
# 0      01.02.2023 00:00 - 01:00
# 1      01.02.2023 01:00 - 02:00
# 2      01.02.2023 02:00 - 03:00
# 3      01.02.2023 03:00 - 04:00
# 4      01.02.2023 04:00 - 05:00
#
#   PJSC-DOEN_UA-IPS-DE_TRADING_UA-IPS_S000 kWh  1.*  \
# 0                                                f
# 1                                                f
# 2                                                f
# 3                                                f
# 4                                                f
#
#   PJSC-DOEN_UA-IPS-DE_TRADING_UA-IPS_S000 kWh  2.*  \
# 0                                                f
# 1                                                f
# 2                                                f
# 3                                                f
# 4                                                f
#
#   PJSC-DOEN_UA-IPS-DE_TRADING_UA-IPS_S000 kWh  3.*  \
# 0                                                f
# ...

# %%
df.dtypes
# Out:
# Компонент Модуль  Версія Сума                       object
# PJSC-DOEN_UA-IPS-DE_TRADING_UA-IPS_S000 kWh  1.*    object
# PJSC-DOEN_UA-IPS-DE_TRADING_UA-IPS_S000 kWh  2.*    object
# PJSC-DOEN_UA-IPS-DE_TRADING_UA-IPS_S000 kWh  3.*    object
# DE_TRADING_UA-IPS-LLC_TEC_UA-IPS_S000 kWh  1.*      object
#                                                      ...
# TES_TOV_UA-IPS-DE_TRADING_UA-IPS_D000 kWh  2.*      object
# TES_TOV_UA-IPS-DE_TRADING_UA-IPS_D000 kWh  3.*      object
# LLC_TEC_UA-IPS-DE_TRADING_UA-IPS_S000 kWh  1.*      object
# LLC_TEC_UA-IPS-DE_TRADING_UA-IPS_S000 kWh  2.*      object
# LLC_TEC_UA-IPS-DE_TRADING_UA-IPS_S000 kWh  3.*      object
# Length: 469, dtype: object

# %%
df.shape[1]
# Out:
# 469

# %%
df1 = pd.melt(df,id_vars=[0])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10208/3742451462.py in <module>
# ----> 1 df1 = pd.melt(df,id_vars=[0])
#
# c:\users\chulm\pycharmprojects\pythonproject\venv\lib\site-packages\pandas\core\reshape\melt.py in melt(frame, id_vars, value_vars, var_name, value_name, col_level, ignore_index)
#      80             missing = Index(com.flatten(id_vars)).difference(cols)
#      81             if not missing.empty:
# ---> 82                 raise KeyError(
#      83                     "The following 'id_vars' are not present "
#      84                     f"in the DataFrame: {list(missing)}"
#
# KeyError: "The following 'id_vars' are not present in the DataFrame: [0]"
