# %%
import pandas as pd

# %%
df=pd.read_csv("C:/Users/chulm/PycharmProjects/pythonProject/pandas/Data/sp500.csv",index_col="Symbol")

# %%
df.head()
# Out:
#                        Name                  Sector   Price  Dividend Yield  \
# Symbol
# MMM                  3M Co.             Industrials  141.14            2.12
# ABT     Abbott Laboratories             Health Care   39.60            1.82
# ABBV            AbbVie Inc.             Health Care   53.95            3.02
# ACN               Accenture  Information Technology   79.79            2.34
# ACE             ACE Limited              Financials  102.91            2.21
#
#         Price/Earnings  Earnings/Share  Book Value  52 week low  52 week high  \
# Symbol
# MMM              20.33           6.900      26.668       107.15        143.37
# ABT              25.93           1.529      15.573        32.70         40.49
# ABBV             20.87           2.570       2.954        40.10         54.78
# ACN              19.53           4.068       8.326        69.00         85.88
# ACE              10.00          10.293      86.897        84.73        104.07
#
# ...

# %%
df1 = df['Price'].round()

# %%
df['RoundedPrice'] = df1

# %%
df.head()
# Out:
#                        Name                  Sector   Price  Dividend Yield  \
# Symbol
# MMM                  3M Co.             Industrials  141.14            2.12
# ABT     Abbott Laboratories             Health Care   39.60            1.82
# ABBV            AbbVie Inc.             Health Care   53.95            3.02
# ACN               Accenture  Information Technology   79.79            2.34
# ACE             ACE Limited              Financials  102.91            2.21
#
#         Price/Earnings  Earnings/Share  Book Value  52 week low  52 week high  \
# Symbol
# MMM              20.33           6.900      26.668       107.15        143.37
# ABT              25.93           1.529      15.573        32.70         40.49
# ABBV             20.87           2.570       2.954        40.10         54.78
# ACN              19.53           4.068       8.326        69.00         85.88
# ACE              10.00          10.293      86.897        84.73        104.07
#
# ...

# %%
df.drop(['RoundedPrice'],axis=1)
# Out:
#                        Name                  Sector   Price  Dividend Yield  \
# Symbol
# MMM                  3M Co.             Industrials  141.14            2.12
# ABT     Abbott Laboratories             Health Care   39.60            1.82
# ABBV            AbbVie Inc.             Health Care   53.95            3.02
# ACN               Accenture  Information Technology   79.79            2.34
# ACE             ACE Limited              Financials  102.91            2.21
# ...                     ...                     ...     ...             ...
# YHOO             Yahoo Inc.  Information Technology   35.02             NaN
# YUM         Yum! Brands Inc  Consumer Discretionary   74.77            1.93
# ZMH         Zimmer Holdings             Health Care  101.84            0.81
# ZION          Zions Bancorp              Financials   28.43            0.56
# ZTS              Zoetis Inc             Health Care   30.53            0.90
#
# ...

# %%
df.head()
# Out:
#                        Name                  Sector   Price  Dividend Yield  \
# Symbol
# MMM                  3M Co.             Industrials  141.14            2.12
# ABT     Abbott Laboratories             Health Care   39.60            1.82
# ABBV            AbbVie Inc.             Health Care   53.95            3.02
# ACN               Accenture  Information Technology   79.79            2.34
# ACE             ACE Limited              Financials  102.91            2.21
#
#         Price/Earnings  Earnings/Share  Book Value  52 week low  52 week high  \
# Symbol
# MMM              20.33           6.900      26.668       107.15        143.37
# ABT              25.93           1.529      15.573        32.70         40.49
# ABBV             20.87           2.570       2.954        40.10         54.78
# ACN              19.53           4.068       8.326        69.00         85.88
# ACE              10.00          10.293      86.897        84.73        104.07
#
# ...

# %%
df1=df[df['Price']>19]

# %%
df1.sort_values(by='Price')
# Out:
#                          Name                  Sector    Price  \
# Symbol
# PHM          Pulte Homes Inc.  Consumer Discretionary    19.70
# AMAT    Applied Materials Inc  Information Technology    20.04
# ETFC                  E-Trade              Financials    20.32
# FITB      Fifth Third Bancorp              Financials    20.54
# MAS               Masco Corp.             Industrials    21.28
# ...                       ...                     ...      ...
# AZO              AutoZone Inc  Consumer Discretionary   540.90
# GOOG              Google Inc.  Information Technology   552.70
# AAPL               Apple Inc.  Information Technology   614.13
# GHC        Graham Holdings Co  Consumer Discretionary   677.29
# PCLN        Priceline.com Inc             Industrials  1197.12
#
#         Dividend Yield  Price/Earnings  Earnings/Share  Book Value  \
# Symbol
# PHM               1.04            2.86           6.714      12.300
# ...
