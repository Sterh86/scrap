# %%
import pandas as pd 
import numpy as np

# %%
sp500 = pd.read_csv("D:\OneDrive\Обучение\Phyton\Хейдт М. Изучаем pandas 2018\Data\Data\sp500.csv")

# %%
sp500
# Out:
#     Symbol                 Name                  Sector   Price  \
# 0      MMM               3M Co.             Industrials  141.14
# 1      ABT  Abbott Laboratories             Health Care   39.60
# 2     ABBV          AbbVie Inc.             Health Care   53.95
# 3      ACN            Accenture  Information Technology   79.79
# 4      ACE          ACE Limited              Financials  102.91
# ..     ...                  ...                     ...     ...
# 495   YHOO           Yahoo Inc.  Information Technology   35.02
# 496    YUM      Yum! Brands Inc  Consumer Discretionary   74.77
# 497    ZMH      Zimmer Holdings             Health Care  101.84
# 498   ZION        Zions Bancorp              Financials   28.43
# 499    ZTS           Zoetis Inc             Health Care   30.53
#
#      Dividend Yield  Price/Earnings  Earnings/Share  Book Value  52 week low  \
# 0              2.12           20.33           6.900      26.668       107.15
# ...

# %%
sp500[(sp500['Price']>50) & (sp500['Book Value']<10)]
# Out:
#     Symbol                         Name                   Sector    Price  \
# 2     ABBV                  AbbVie Inc.              Health Care   53.950
# 3      ACN                    Accenture   Information Technology   79.790
# 18    ALLE                 Allegion plc              Industrials   52.460
# 29     AMT        American Tower Corp A               Financials   88.410
# 31     ABC       AmerisourceBergen Corp              Health Care   71.640
# 48     AZO                 AutoZone Inc   Consumer Discretionary  540.900
# 53     BLL                    Ball Corp                Materials   60.220
# 73    BF-B     Brown-Forman Corporation         Consumer Staples   91.420
# 90    CERN                       Cerner              Health Care   53.120
# 92    CHRW     C. H. Robinson Worldwide              Industrials   59.630
# 104    CLX                   Clorox Co.         Consumer Staples   88.330
# 111     CL            Colgate-Palmolive         Consumer Staples   66.730
# ...

# %%
unq=pd.DataFrame({'Sektor': sp500['Sector'].unique()})

# %%
unq
# Out:
#                          Sektor
# 0                   Industrials
# 1                   Health Care
# 2        Information Technology
# 3                    Financials
# 4                     Utilities
# 5                     Materials
# 6              Consumer Staples
# 7        Consumer Discretionary
# 8                        Energy
# 9   Telecommunications Services
# 10            Consumer Staples
# 11                   Industries
# 12      Consumer Discretionary

# %%
unq['Num'] = np.arange(0,13)

# %%
unq
# Out:
#                          Sektor  Num
# 0                   Industrials    0
# 1                   Health Care    1
# 2        Information Technology    2
# 3                    Financials    3
# 4                     Utilities    4
# 5                     Materials    5
# 6              Consumer Staples    6
# 7        Consumer Discretionary    7
# 8                        Energy    8
# 9   Telecommunications Services    9
# 10            Consumer Staples    10
# 11                   Industries   11
# 12      Consumer Discretionary    12

# %%
unq[:5]
# Out:
#                    Sektor  Num
# 0             Industrials    0
# 1             Health Care    1
# 2  Information Technology    2
# 3              Financials    3
# 4               Utilities    4

# %%
pd.merge(sp500,ung)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_19808/259802075.py in <module>
# ----> 1 pd.merge(sp500,ung)
#
# NameError: name 'ung' is not defined
